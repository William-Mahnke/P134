# %% [markdown]
# ## Lab 1: Python Code
# ### Star Wars Case Study

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# read in starwars data from R
starwars = pd.read_csv("~/Desktop/P134/starwars.csv")

# %%
starwars
# Out:
#               name  height   mass hair_color   skin_color eye_color  \
# 0   Luke Skywalker   172.0   77.0      blond         fair      blue
# 1            C-3PO   167.0   75.0        NaN         gold    yellow
# 2            R2-D2    96.0   32.0        NaN  white, blue       red
# 3      Darth Vader   202.0  136.0       none        white    yellow
# 4      Leia Organa   150.0   49.0      brown        light     brown
# ..             ...     ...    ...        ...          ...       ...
# 82            Finn     NaN    NaN      black         dark      dark
# 83             Rey     NaN    NaN      brown        light     hazel
# 84     Poe Dameron     NaN    NaN      brown        light     brown
# 85             BB8     NaN    NaN       none         none     black
# 86  Captain Phasma     NaN    NaN       none         none   unknown
#
#     birth_year     sex     gender homeworld species  films  vehicles  \
# 0         19.0    male  masculine  Tatooine   Human    NaN       NaN
# ...

# %%
# 1. How many rows are in starwars? How many columns?
rows, cols = starwars.shape
print(f"Rows: {rows}\nColumns: {cols}")

# 2. What does `vehicles` variable describe?
# describes the vehicles used by a character in the show - was stored as a list in R which
# is why the column in all NaNs

# %%
starwars_smaller = starwars.loc[:,['name','height','species','gender']]
starwars_smaller = starwars_smaller[starwars_smaller['height'] >= 0]
starwars_smaller
# Out:
#                name  height  species     gender
# 0    Luke Skywalker   172.0    Human  masculine
# 1             C-3PO   167.0    Droid  masculine
# 2             R2-D2    96.0    Droid  masculine
# 3       Darth Vader   202.0    Human  masculine
# 4       Leia Organa   150.0    Human   feminine
# ..              ...     ...      ...        ...
# 77         Grievous   216.0  Kaleesh  masculine
# 78          Tarfful   234.0  Wookiee  masculine
# 79  Raymus Antilles   188.0    Human  masculine
# 80        Sly Moore   178.0      NaN        NaN
# 81       Tion Medon   206.0   Pau'an  masculine
#
# [81 rows x 4 columns]

# %%
# 1. What is the purpose of `starwars_smaller['height']` is?
starwars_smaller['height'] >= 0
# assigns boolean to each observation which allows for flitering particular
# observations
starwars_smaller['height'].describe()
starwars_smaller.groupby('gender')['height'].describe()
# Out:
#            count        mean        std   min     25%    50%    75%    max
# gender
# feminine    15.0  166.533333  24.816085  96.0  164.00  167.0  178.0  213.0
# masculine   62.0  176.532258  37.646204  66.0  171.25  183.0  193.0  264.0

# %%
# histogram of character heights
plt.hist(starwars_smaller['height'])
plt.title("Distribution of Character Heights")
plt.xlabel("Height in cm")
plt.show()

# %%
# histogram and density plot split by gender
sns.histplot(data = starwars_smaller, x = 'height', hue = 'gender',
             multiple = 'stack', bins = 15, kde = True)
plt.title("Distribution of Height by Genders")
plt.legend(title = 'Gender', labels = ['Female','Male'])
plt.show()

# %%
# Exercises
# 1. Identify characters with missing gender identity
starwars_gender_na = starwars[starwars['gender'].isna()]
starwars_gender_na
# Out:
#                 name  height   mass hair_color skin_color eye_color  \
# 17  Jek Tono Porkins   180.0  110.0      brown       fair      blue
# 58      Gregar Typho   185.0   85.0      black       dark     brown
# 59             Cordé   157.0    NaN      brown      light     brown
# 80         Sly Moore   178.0   48.0       none       pale     white
#
#     birth_year  sex gender   homeworld species  films  vehicles  starships
# 17         NaN  NaN    NaN  Bestine IV     NaN    NaN       NaN        NaN
# 58         NaN  NaN    NaN       Naboo     NaN    NaN       NaN        NaN
# 59         NaN  NaN    NaN       Naboo     NaN    NaN       NaN        NaN
# 80         NaN  NaN    NaN      Umbara     NaN    NaN       NaN        NaN
